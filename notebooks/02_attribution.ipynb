# %% [markdown]
# # Attribution
#
# Inspect the factor attribution table for the default target.

# %%
from pathlib import Path
import sys

PROJECT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT))

import pandas as pd
from IPython.display import Image, display

target_attr = pd.read_csv(PROJECT / 'reports' / 'target_attribution.csv', index_col=0)
strategy_attr = pd.read_csv(PROJECT / 'reports' / 'strategy_factor_attribution.csv', index_col=0)
display(target_attr)
display(strategy_attr)

# %%
path = PROJECT / 'reports' / 'figures' / 'target_carhart_loadings.png'
if path.exists():
    display(Image(filename=str(path)))
